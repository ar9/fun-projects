# %%
import sys
from pathlib import Path

SRC_DIR = Path("../src").resolve()
sys.path.append(str(SRC_DIR))

# %%
from config import GAME_DATA_FILE, AGENT_SYSTEM_PROMPT_FILE
from loaders import load_text, build_agent_prompt_text, safe_json_load, parse_council_df

from dotenv import load_dotenv

from lm_council import LanguageModelCouncil
from lm_council.judging import PRESET_EVAL_CONFIGS

from aiolimiter import AsyncLimiter

import json
import yaml
import pandas as pd
from json_repair import repair_json

# %%
load_dotenv()
# Out:
# True

# %%
lmc = LanguageModelCouncil(
models = [
                "x-ai/grok-code-fast-1",
                "anthropic/claude-sonnet-4.5",
                "google/gemini-2.5-flash",
                "openai/gpt-5-mini",
                "deepseek/deepseek-chat-v3-0324",
                "minimax/minimax-m2",
                "z-ai/glm-4.6",
                "qwen/qwen3-235b-a22b-2507",
            ],
judge_models=[
    "x-ai/grok-code-fast-1"],
eval_config=PRESET_EVAL_CONFIGS["default_rubric"],
)

# %%
# Load both text files
game_data_text = load_text(GAME_DATA_FILE)
agent_system_prompt = load_text(AGENT_SYSTEM_PROMPT_FILE)

# Build combined prompt
full_prompt = build_agent_prompt_text(agent_system_prompt, game_data_text)

# %%
lmc._limiter = AsyncLimiter(5, 30)

council_raw, council_judgment = await lmc.execute(full_prompt)
# Out:
# Generated 8 completion tasks.
# 100%|██████████| 8/8 [00:36<00:00,  4.52s/it]
# Generated 8 judging tasks.
# 100%|██████████| 8/8 [00:32<00:00,  4.12s/it]

# %%
council_raw
# Out:
#                                          user_prompt  ... total_tokens
# 0  You are one member of an independent LLM Predi...  ...         3231
# 1  You are one member of an independent LLM Predi...  ...         3732
# 2  You are one member of an independent LLM Predi...  ...         3555
# 3  You are one member of an independent LLM Predi...  ...         2775
# 4  You are one member of an independent LLM Predi...  ...         3394
# 5  You are one member of an independent LLM Predi...  ...         2866
# 6  You are one member of an independent LLM Predi...  ...         3376
# 7  You are one member of an independent LLM Predi...  ...         4603
#
# [8 rows x 6 columns]

# %%
parsed = parse_council_df(council_raw)

# %%
display(parsed)
# Out:
#                             model  ...                                       risk_factors
# 0         google/gemini-2.5-flash  ...  [Texas has a significant home-field advantage,...
# 1                    z-ai/glm-4.6  ...  [TAMU's superior offensive production (37.1 pp...
# 2           x-ai/grok-code-fast-1  ...  [Texas A&M has multiple key injuries including...
# 3  deepseek/deepseek-chat-v3-0324  ...  [Texas A&M has a superior overall record (11-0...
# 4              minimax/minimax-m2  ...  [TAMU has superior offensive production (37.1 ...
# 5       qwen/qwen3-235b-a22b-2507  ...  [Texas has a strong home-field advantage at DK...
# 6     anthropic/claude-sonnet-4.5  ...  [Texas A&M missing two starting safeties (Bryc...
# 7               openai/gpt-5-mini  ...  [TAMU offensive dominance: TAMU stats.points_s...
#
# [8 rows x 10 columns]

# %%
council_judgment
# Out:
#                                          user_prompt  ... Overall
# 0  You are one member of an independent LLM Predi...  ...     5.0
# 1  You are one member of an independent LLM Predi...  ...     5.0
# 2  You are one member of an independent LLM Predi...  ...     5.0
# 3  You are one member of an independent LLM Predi...  ...     5.0
# 4  You are one member of an independent LLM Predi...  ...     5.0
# 5  You are one member of an independent LLM Predi...  ...     5.0
# 6  You are one member of an independent LLM Predi...  ...     5.0
# 7  You are one member of an independent LLM Predi...  ...     5.0
#
# [8 rows x 10 columns]

# %%
lmc.save("run_3")
lmc.load("run_3")
